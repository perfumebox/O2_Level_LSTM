# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.layers import *
from keras.models import *
from keras.utils import *
from sklearn.preprocessing import *

# %%
feat = ['feat_{}'.format(i) for i in range(74)]

df = pd.read_csv('./dataset/eighthr.data', names=feat)

df
# Out:
#           feat_0 feat_1 feat_2 feat_3 feat_4 feat_5 feat_6 feat_7 feat_8  \
# 0       1/1/1998    0.8    1.8    2.4    2.1      2    2.1    1.5    1.7
# 1       1/2/1998    2.8    3.2    3.3    2.7    3.3    3.2    2.9    2.8
# 2       1/3/1998    2.9    2.8    2.6    2.1    2.2    2.5    2.5    2.7
# 3       1/4/1998    4.7    3.8    3.7    3.8    2.9    3.1    2.8    2.5
# 4       1/5/1998    2.6    2.1    1.6    1.4    0.9    1.5    1.2    1.4
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2529  12/27/2004    0.3    0.4    0.5    0.5    0.2    0.3    0.4    0.4
# 2530  12/28/2004      1    1.4    1.1    1.7    1.5    1.7    1.8    1.5
# 2531  12/29/2004    0.8    0.8    1.2    0.9    0.4    0.6    0.8    1.1
# 2532  12/30/2004    1.3    0.9    1.5    1.2    1.6    1.8    1.1      1
# 2533  12/31/2004    1.5    1.3    1.8    1.4    1.2    1.7    1.6    1.4
#
#      feat_9  ... feat_64 feat_65 feat_66 feat_67 feat_68 feat_69 feat_70  \
# 0       1.9  ...    0.15   10.67   -1.56    5795   -12.1    17.9   10330
# 1       3.1  ...    0.48    8.39    3.84    5805   14.05      29   10275
# 2       2.2  ...     0.6    6.94     9.8    5790    17.9    41.3   10235
# 3       2.4  ...    0.49    8.73   10.54    5775   31.15    51.7   10195
# 4       1.3  ...       ?       ?       ?       ?       ?       ?       ?
# ...     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 2529    1.3  ...    0.07    7.93   -4.41    5800   -25.6    21.8   10295
# 2530    2.1  ...    0.04    5.95   -1.14    5845   -19.4    19.1   10310
# 2531    1.5  ...    0.06     7.8   -0.64    5845    -9.6    35.2   10275
# 2532    1.9  ...    0.25    7.72   -0.89    5845   -19.6    34.2   10245
# 2533    1.6  ...    0.54   13.07    9.15    5820    1.95   39.35   10220
#
#      feat_71 feat_72 feat_73
# 0        -55       0     0.0
# 1        -55       0     0.0
# 2        -40       0     0.0
# 3        -40    2.08     0.0
# 4          ?    0.58     0.0
# ...      ...     ...     ...
# 2529      65       0     0.0
# 2530      15       0     0.0
# 2531     -35       0     0.0
# 2532     -30    0.05     0.0
# 2533     -25       0     0.0
#
# [2534 rows x 74 columns]

# %%
df.dtypes
# Out:
# feat_0      object
# feat_1      object
# feat_2      object
# feat_3      object
# feat_4      object
#             ...
# feat_69     object
# feat_70     object
# feat_71     object
# feat_72     object
# feat_73    float64
# Length: 74, dtype: object

# %%
#데이터 타입변경
df1 = df.apply(pd.to_numeric, errors='coerce')
df1 = df1.drop(['feat_0'], axis=1)
df1
# Out:
#       feat_1  feat_2  feat_3  feat_4  feat_5  feat_6  feat_7  feat_8  feat_9  \
# 0        0.8     1.8     2.4     2.1     2.0     2.1     1.5     1.7     1.9
# 1        2.8     3.2     3.3     2.7     3.3     3.2     2.9     2.8     3.1
# 2        2.9     2.8     2.6     2.1     2.2     2.5     2.5     2.7     2.2
# 3        4.7     3.8     3.7     3.8     2.9     3.1     2.8     2.5     2.4
# 4        2.6     2.1     1.6     1.4     0.9     1.5     1.2     1.4     1.3
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2529     0.3     0.4     0.5     0.5     0.2     0.3     0.4     0.4     1.3
# 2530     1.0     1.4     1.1     1.7     1.5     1.7     1.8     1.5     2.1
# 2531     0.8     0.8     1.2     0.9     0.4     0.6     0.8     1.1     1.5
# 2532     1.3     0.9     1.5     1.2     1.6     1.8     1.1     1.0     1.9
# 2533     1.5     1.3     1.8     1.4     1.2     1.7     1.6     1.4     1.6
#
#       feat_10  ...  feat_64  feat_65  feat_66  feat_67  feat_68  feat_69  \
# 0         2.3  ...     0.15    10.67    -1.56   5795.0   -12.10    17.90
# 1         3.4  ...     0.48     8.39     3.84   5805.0    14.05    29.00
# 2         2.5  ...     0.60     6.94     9.80   5790.0    17.90    41.30
# 3         3.1  ...     0.49     8.73    10.54   5775.0    31.15    51.70
# 4         1.4  ...      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...  ...      ...      ...      ...      ...      ...      ...
# 2529      2.2  ...     0.07     7.93    -4.41   5800.0   -25.60    21.80
# 2530      2.4  ...     0.04     5.95    -1.14   5845.0   -19.40    19.10
# 2531      1.5  ...     0.06     7.80    -0.64   5845.0    -9.60    35.20
# 2532      2.0  ...     0.25     7.72    -0.89   5845.0   -19.60    34.20
# 2533      3.0  ...     0.54    13.07     9.15   5820.0     1.95    39.35
#
#       feat_70  feat_71  feat_72  feat_73
# 0     10330.0    -55.0     0.00      0.0
# 1     10275.0    -55.0     0.00      0.0
# 2     10235.0    -40.0     0.00      0.0
# 3     10195.0    -40.0     2.08      0.0
# 4         NaN      NaN     0.58      0.0
# ...       ...      ...      ...      ...
# 2529  10295.0     65.0     0.00      0.0
# 2530  10310.0     15.0     0.00      0.0
# 2531  10275.0    -35.0     0.00      0.0
# 2532  10245.0    -30.0     0.05      0.0
# 2533  10220.0    -25.0     0.00      0.0
#
# [2534 rows x 73 columns]

# %%
df1.dropna(inplace=True)
df1
# Out:
#       feat_1  feat_2  feat_3  feat_4  feat_5  feat_6  feat_7  feat_8  feat_9  \
# 0        0.8     1.8     2.4     2.1     2.0     2.1     1.5     1.7     1.9
# 1        2.8     3.2     3.3     2.7     3.3     3.2     2.9     2.8     3.1
# 2        2.9     2.8     2.6     2.1     2.2     2.5     2.5     2.7     2.2
# 3        4.7     3.8     3.7     3.8     2.9     3.1     2.8     2.5     2.4
# 6        3.7     3.2     3.8     5.1     6.0     7.0     6.3     6.4     6.3
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2529     0.3     0.4     0.5     0.5     0.2     0.3     0.4     0.4     1.3
# 2530     1.0     1.4     1.1     1.7     1.5     1.7     1.8     1.5     2.1
# 2531     0.8     0.8     1.2     0.9     0.4     0.6     0.8     1.1     1.5
# 2532     1.3     0.9     1.5     1.2     1.6     1.8     1.1     1.0     1.9
# 2533     1.5     1.3     1.8     1.4     1.2     1.7     1.6     1.4     1.6
#
#       feat_10  ...  feat_64  feat_65  feat_66  feat_67  feat_68  feat_69  \
# 0         2.3  ...     0.15    10.67    -1.56   5795.0   -12.10    17.90
# 1         3.4  ...     0.48     8.39     3.84   5805.0    14.05    29.00
# 2         2.5  ...     0.60     6.94     9.80   5790.0    17.90    41.30
# 3         3.1  ...     0.49     8.73    10.54   5775.0    31.15    51.70
# 6         5.4  ...     0.84     6.86    25.60   5695.0    26.75    48.45
# ...       ...  ...      ...      ...      ...      ...      ...      ...
# 2529      2.2  ...     0.07     7.93    -4.41   5800.0   -25.60    21.80
# 2530      2.4  ...     0.04     5.95    -1.14   5845.0   -19.40    19.10
# 2531      1.5  ...     0.06     7.80    -0.64   5845.0    -9.60    35.20
# 2532      2.0  ...     0.25     7.72    -0.89   5845.0   -19.60    34.20
# 2533      3.0  ...     0.54    13.07     9.15   5820.0     1.95    39.35
#
#       feat_70  feat_71  feat_72  feat_73
# 0     10330.0    -55.0     0.00      0.0
# 1     10275.0    -55.0     0.00      0.0
# 2     10235.0    -40.0     0.00      0.0
# 3     10195.0    -40.0     2.08      0.0
# 6     10040.0    -80.0     0.18      0.0
# ...       ...      ...      ...      ...
# 2529  10295.0     65.0     0.00      0.0
# 2530  10310.0     15.0     0.00      0.0
# 2531  10275.0    -35.0     0.00      0.0
# 2532  10245.0    -30.0     0.05      0.0
# 2533  10220.0    -25.0     0.00      0.0
#
# [1847 rows x 73 columns]

# %%
Y = df1['feat_73']
Y = to_categorical(Y)

df1.drop(['feat_73'], axis=1, inplace=True)

X_train = np.asarray(df1[:-100].values.tolist(), dtype=np.float64)
X_test = np.asarray(df1[-100:].values.tolist(), dtype=np.float64)

Y_train = Y[:-100]
Y_test = Y[-100:]

X_train = X_train[:1700]
Y_train = Y_train[:1700]

X_train = X_train.reshape(-1, 10, 72)
Y_train = Y_train.reshape(-1, 10, 2)
X_test = X_test.reshape(-1, 10, 72)
Y_test = Y_test.reshape(-1, 10, 2)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(10, 72,), return_sequences=True))
model.add(LSTM(256, return_sequences=True))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 128)           102912
#
#  lstm_1 (LSTM)               (None, 10, 256)           394240
#
#  dense (Dense)               (None, 10, 2)             514
#
# =================================================================
# Total params: 497,666
# Trainable params: 497,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(X_train.shape)
hist = model.fit(X_train, Y_train, epochs=10, batch_size=1, validation_split=0.2)
# Out:
# (170, 10, 72)
# Epoch 1/10
# 136/136 [==============================] - 3s 13ms/step - loss: 0.3210 - accuracy: 0.9125 - val_loss: 0.1907 - val_accuracy: 0.9588
# Epoch 2/10
# 136/136 [==============================] - 1s 10ms/step - loss: 0.2853 - accuracy: 0.9199 - val_loss: 0.1736 - val_accuracy: 0.9588
# Epoch 3/10
# 136/136 [==============================] - 1s 10ms/step - loss: 0.2785 - accuracy: 0.9199 - val_loss: 0.1728 - val_accuracy: 0.9588
# Epoch 4/10
# 136/136 [==============================] - 1s 10ms/step - loss: 0.2849 - accuracy: 0.9199 - val_loss: 0.1812 - val_accuracy: 0.9588
# Epoch 5/10
# 136/136 [==============================] - 1s 10ms/step - loss: 0.2850 - accuracy: 0.9199 - val_loss: 0.2213 - val_accuracy: 0.9588
# Epoch 6/10
# 136/136 [==============================] - 1s 10ms/step - loss: 0.2851 - accuracy: 0.9199 - val_loss: 0.1853 - val_accuracy: 0.9588
# Epoch 7/10
# 136/136 [==============================] - 1s 9ms/step - loss: 0.2839 - accuracy: 0.9199 - val_loss: 0.2024 - val_accuracy: 0.9588
# Epoch 8/10
# 136/136 [==============================] - 1s 9ms/step - loss: 0.2864 - accuracy: 0.9199 - val_loss: 0.1940 - val_accuracy: 0.9588
# Epoch 9/10
# 136/136 [==============================] - 1s 9ms/step - loss: 0.2827 - accuracy: 0.9199 - val_loss: 0.1777 - val_accuracy: 0.9588
# Epoch 10/10
# 136/136 [==============================] - 1s 11ms/step - loss: 0.2838 - accuracy: 0.9199 - val_loss: 0.1762 - val_accuracy: 0.9588
